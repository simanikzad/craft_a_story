# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
income = pd.read_csv('/Users/sima/Desktop/springboard/adult.csv')
income.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
income = income.rename(columns={"marital-status": "marital_status", "educational-num": "educational_num", "hours-per-week": "hours_per_week", "native-country": "native_country", "capital-loss" : "capital_loss", "capital-gain": "capital_gain" })
income
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
income['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
income['workclass'].unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
#income = income[income['workclass'] == '?']
#income

# %%
income = income[income['native_country'] == 'United-States']
income
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
missing = pd.concat([income.isnull().sum(), 100 * income.isnull().mean()], axis=1)

missing.columns=['count', '%']
missing.sort_values(by = 'count', ascending=False)
# Out:
#                  count    %
# age                  0  0.0
# workclass            0  0.0
# fnlwgt               0  0.0
# education            0  0.0
# educational_num      0  0.0
# marital_status       0  0.0
# occupation           0  0.0
# relationship         0  0.0
# race                 0  0.0
# gender               0  0.0
# capital_gain         0  0.0
# capital_loss         0  0.0
# hours_per_week       0  0.0
# native_country       0  0.0
# income               0  0.0

# %%
income['income'].isna().sum()
# Out:
# 0

# %%
income['income'] = income['income'].replace({'<=50K' : 1, '>50K': 0})
income.head()
# Out:
# <ipython-input-10-5250659bd19a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income['income'] = income['income'].replace({'<=50K' : 1, '>50K': 0})
#    age  workclass  fnlwgt     education  educational_num      marital_status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital_gain  capital_loss  \
# ...

# %%
count_by_gender = income.groupby(['education', 'gender'])['income'].value_counts()
count_by_gender
# Out:
# education     gender  income
# 10th          Female  1          415
#                       0            2
#               Male    1          761
#                       0           81
# 11th          Female  1          587
#                       0           10
#               Male    1          982
#                       0           75
# 12th          Female  1          179
#                       0            4
#               Male    1          336
#                       0           38
# 1st-4th       Female  1           19
#               Male    1           42
#                       0            2
# 5th-6th       Female  1           29
#               Male    1          122
#                       0            8
# 7th-8th       Female  1          176
#               Male    1          518
#                       0           47
# 9th           Female  1          159
#                       0            4
#               Male    1          394
# ...

# %%
count_by_gender_stacked =count_by_gender.unstack()
count_by_gender_stacked
# Out:
# income                    0       1
# education    gender
# 10th         Female     2.0   415.0
#              Male      81.0   761.0
# 11th         Female    10.0   587.0
#              Male      75.0   982.0
# 12th         Female     4.0   179.0
#              Male      38.0   336.0
# 1st-4th      Female     NaN    19.0
#              Male       2.0    42.0
# 5th-6th      Female     NaN    29.0
#              Male       8.0   122.0
# 7th-8th      Female     NaN   176.0
#              Male      47.0   518.0
# 9th          Female     4.0   159.0
#              Male      31.0   394.0
# Assoc-acdm   Female    78.0   496.0
#              Male     307.0   589.0
# Assoc-voc    Female    87.0   590.0
#              Male     398.0   843.0
# Bachelors    Female   467.0  1742.0
#              Male    2553.0  2422.0
# Doctorate    Female    60.0    40.0
#              Male     293.0    85.0
# HS-grad      Female   301.0  4381.0
#              Male    2051.0  7837.0
# ...

# %%
count_by_gender_stacked .fillna(0)
# Out:
# income                    0       1
# education    gender
# 10th         Female     2.0   415.0
#              Male      81.0   761.0
# 11th         Female    10.0   587.0
#              Male      75.0   982.0
# 12th         Female     4.0   179.0
#              Male      38.0   336.0
# 1st-4th      Female     0.0    19.0
#              Male       2.0    42.0
# 5th-6th      Female     0.0    29.0
#              Male       8.0   122.0
# 7th-8th      Female     0.0   176.0
#              Male      47.0   518.0
# 9th          Female     4.0   159.0
#              Male      31.0   394.0
# Assoc-acdm   Female    78.0   496.0
#              Male     307.0   589.0
# Assoc-voc    Female    87.0   590.0
#              Male     398.0   843.0
# Bachelors    Female   467.0  1742.0
#              Male    2553.0  2422.0
# Doctorate    Female    60.0    40.0
#              Male     293.0    85.0
# HS-grad      Female   301.0  4381.0
#              Male    2051.0  7837.0
# ...

# %%
count_by_gender_stacked.plot(kind='bar', figsize=(10, 10))
plt.title('Income by gender')
# Out:
# Text(0.5, 1.0, 'Income by gender')

# %%
fig = plt.figure(figsize=(10,10)) 
sns.boxplot(x="income", y="age", data=income)
plt.show()

# %%
income[['age', 'income']].groupby(['income'], as_index=False).mean()
# Out:
#    income        age
# 0       0  44.324855
# 1       1  36.883065

# %%
fig = plt.figure(figsize=(20,10))
ax = sns.countplot(x="gender", hue='income' , data=income)

# %%
percentage_by_gen = pd.concat([income.isnull().sum(), 100 * income.isnull().mean()], axis=1)

missing.columns=['count', '%']
missing.sort_values(by = 'count', ascending=False)
# Out:
#                  count    %
# age                  0  0.0
# workclass            0  0.0
# fnlwgt               0  0.0
# education            0  0.0
# educational_num      0  0.0
# marital_status       0  0.0
# occupation           0  0.0
# relationship         0  0.0
# race                 0  0.0
# gender               0  0.0
# capital_gain         0  0.0
# capital_loss         0  0.0
# hours_per_week       0  0.0
# native_country       0  0.0
# income               0  0.0

# %%
plt.figure(figsize = (12,6))
sns.boxplot(x='income', y='age', hue='gender', data=income)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='income', y='hours_per_week', data=income)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='income', y ='hours_per_week', hue='gender',data=income)
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = sns.countplot(x="education", hue='income' , data=income)

# %%
fig = plt.figure(figsize=(20,10))
ax = sns.countplot(x='workclass', hue='income', data= income)

# %%
income['gender'].value_counts(normalize=True)
# Out:
# Male      0.666705
# Female    0.333295
# Name: gender, dtype: float64

# %%
df_dropna = pd.DataFrame(income, columns=["gender", "income"])
df = df_dropna.groupby('income')['gender'].value_counts()
df.head()
#by_gender = income.groupby(['income','gender'])
#by_gender.head()
# Out:
# income  gender
# 0       Male       9081
#         Female     1613
# 1       Male      20142
#         Female    12996
# Name: gender, dtype: int64

# %%
 fig = plt.figure(figsize=(20,10))
ax = sns.countplot(x="income", hue='gender' , data=income)

# %%
fig =plt.figure(figsize= (20,10))
ax = sns.countplot(x='income', hue='race', data=income)

# %%
count_by_race = income.groupby(['education', 'race'])['income'].value_counts()
count_by_race
# Out:
# education     race                income
# 10th          Amer-Indian-Eskimo  1           21
#               Asian-Pac-Islander  1            3
#               Black               1          165
#                                   0            6
#               Other               1            5
#                                             ...
# Some-college  Black               0          114
#               Other               1           42
#                                   0            8
#               White               1         7039
#                                   0         1773
# Name: income, Length: 126, dtype: int64

# %%
count_by_race_stack = count_by_race.unstack()
count_by_race_stack
# Out:
# income                                0       1
# education    race
# 10th         Amer-Indian-Eskimo     NaN    21.0
#              Asian-Pac-Islander     NaN     3.0
#              Black                  6.0   165.0
#              Other                  1.0     5.0
#              White                 76.0   982.0
# ...                                 ...     ...
# Some-college Amer-Indian-Eskimo    18.0   104.0
#              Asian-Pac-Islander    26.0   100.0
#              Black                114.0   870.0
#              Other                  8.0    42.0
#              White               1773.0  7039.0
#
# [76 rows x 2 columns]

# %%
count_by_race_stack.fillna(0)
# Out:
# income                                0       1
# education    race
# 10th         Amer-Indian-Eskimo     0.0    21.0
#              Asian-Pac-Islander     0.0     3.0
#              Black                  6.0   165.0
#              Other                  1.0     5.0
#              White                 76.0   982.0
# ...                                 ...     ...
# Some-college Amer-Indian-Eskimo    18.0   104.0
#              Asian-Pac-Islander    26.0   100.0
#              Black                114.0   870.0
#              Other                  8.0    42.0
#              White               1773.0  7039.0
#
# [76 rows x 2 columns]

# %%
count_by_race_stack.plot(kind='bar', figsize =(20,30))
plt.title('race')
# Out:
# Text(0.5, 1.0, 'race')
